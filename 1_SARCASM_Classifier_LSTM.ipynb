# %%
import os
import sys
from pathlib import Path

import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

import re
from typing import *
from helper import to_sequences, to_padding

import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# ### 1.Reading the data

# %%
data_path = Path("data/got/game_of_thrones.txt")

# %%
df = pd.read_csv(data_path, sep='\t', header=None, names=["got_text"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7083 entries, 0 to 7082
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   got_text  7083 non-null   object
# dtypes: object(1)
# memory usage: 55.5+ KB

# %%
df.head()
# Out:
#                                             got_text
# 0                             A Song of Ice and Fire
# 1                                  A Game of Thrones
# 2                                           PROLOGUE
# 3  We should start back, Gared urged as the woods...
# 4  Do the dead frighten you? Ser Waymar Royce ask...

# %%
# Converting each line to a list
sentences = df['got_text'].apply(lambda x: x.lower()).to_list()

# %%
sentences[:3]
# Out:
# ['a song of ice and fire', 'a game of thrones', 'prologue']

# %% [markdown]
# ### 2.Cleaning the Data

# %% [markdown]
# * All words are converted to Lower case

# %%
MAX_LENGTH = 0
lens = []
for each_sentence in sentences:
    temp_len = len(each_sentence)
    lens.append(temp_len)
    if MAX_LENGTH<temp_len:
        MAX_LENGTH = temp_len

print(MAX_LENGTH, np.mean(lens))
# Out:
# 1603 224.711986446421

# %% [markdown]
# ### 4.Preprocessing --> Tokenization, Sequences and Padding

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# Vocabulary size of the tokenizer
VOCAB_SIZE = 10000

# Maximum length of clean sentence is  217
# Giving 50 as the max length including the padded sequences
MAX_LENGTH = 225

# Output dimensions of the Embedding layer
EMBEDDING_DIM = 16

# Parameters for padding and OOV tokens
TRUNC_TYPE = 'pre'
PADDING_TYPE = 'pre'
OOV_TOKEN = "<OOV>"

# %%
def get_tokenizer(VOCAB_SIZE, OOV_TOKEN, X_data=sentences):
    # Initialize the Tokenizer class
    tokenizer = Tokenizer(num_words=VOCAB_SIZE, oov_token=OOV_TOKEN)

    # Generate the word index dictionary
    tokenizer.fit_on_texts(X_data)
    
    return tokenizer

def to_sequences_n_padding(tokenizer,MAX_LENGTH,PADDING_TYPE,TRUNC_TYPE,X_data):
    # Generate and pad the training sequences
    _sequences = tokenizer.texts_to_sequences(X_data)
    _padded = pad_sequences(_sequences, 
                            maxlen=MAX_LENGTH, 
                            padding=PADDING_TYPE, 
                            truncating=TRUNC_TYPE)
    
    return _padded   


def seq_gen(sent_seq):
    input_seq = []
    for line in sent_seq:
        for i in range(1, len(line)):
            input_seq.append(line[:i+1])

    return input_seq

# %%
tokenizer = get_tokenizer(VOCAB_SIZE=VOCAB_SIZE,OOV_TOKEN=OOV_TOKEN)

# Define the total words. You add 1 for the index `0` which is just the padding token.
total_words = len(tokenizer.word_index) + 1

print(f'word index dictionary: {tokenizer.word_index}')
print(f'total words: {total_words}')
# Out:
# word index dictionary: {'<OOV>': 1, 'the': 2, 'and': 3, 'to': 4, 'a': 5, 'of': 6, 'his': 7, 'he': 8, 'was': 9, 'her': 10, 'in': 11, 'you': 12, 'it': 13, 'had': 14, 'i': 15, 'she': 16, 'as': 17, 'him': 18, 'with': 19, 'that': 20, 'said': 21, 'not': 22, 'for': 23, 'at': 24, 'on': 25, 'they': 26, 'is': 27, 'but': 28, 'my': 29, 'lord': 30, 'from': 31, 'no': 32, 'them': 33, 'have': 34, 'would': 35, 'were': 36, 'be': 37, 'ser': 38, 'all': 39, 'when': 40, 'your': 41, 'me': 42, 'if': 43, 'will': 44, 'so': 45, 'their': 46, 'could': 47, 'one': 48, 'jon': 49, 'what': 50, 'ned': 51, 'up': 52, 'out': 53, 'are': 54, 'man': 55, 'there': 56, 'this': 57, 'back': 58, 'been': 59, 'do': 60, 'did': 61, 'down': 62, 'by': 63, 'like': 64, 'men': 65, 'tyrion': 66, 'we': 67, 'hand': 68, 'eyes': 69, 'king': 70, 'than': 71, 'now': 72, 'father': 73, 'only': 74, 'told': 75, 'see': 76, 'or': 77, 'bran': 78, 'catelyn': 79, 'more': 80, 'who': 81, 'off': 82, 'arya': 83, 'here': 84, 'an': 85, 'even': 86, 'face': 87, 'over': 88, 'into': 89, 'old': 90, 'know': 91, 'boy': 92, 'black': 93, 'looked': 94, 'never': 95, 'before': 96, 'brother': 97, 'long': 98, 'well': 99, 'time': 100, 'dany': 101, 'sansa': 102, 'then': 103, 'stark': 104, 'robb': 105, 'head': 106, 'made': 107, 'too': 108, 'away': 109, 'yet': 110, 'lady': 111, 'where': 112, 'through': 113, 'robert': 114, 'took': 115, 'come': 116, 'how': 117, 'thought': 118, 'lannister': 119, 'sword': 120, 'maester': 121, 'must': 122, 'came': 123, 'around': 124, 'still': 125, 'blood': 126, 'saw': 127, 'has': 128, 'look': 129, 'way': 130, 'son': 131, 'voice': 132, 'us': 133, 'first': 134, 'take': 135, 'some': 136, 'can': 137, 'go': 138, 'say': 139, 'two': 140, 'red': 141, 'behind': 142, 'again': 143, 'asked': 144, 'other': 145, 'left': 146, 'dead': 147, 'himself': 148, 'tell': 149, 'its': 150, 'want': 151, 'night': 152, 'about': 153, 'might': 154, 'across': 155, 'make': 156, 'after': 157, 'good': 158, 'heard': 159, 'knew': 160, 'last': 161, 'went': 162, 'great': 163, 'horse': 164, 'once': 165, 'day': 166, 'gods': 167, 'gave': 168, "king's": 169, 'own': 170, 'let': 171, 'winterfell': 172, 'little': 173, 'keep': 174, 'high': 175, 'wall': 176, 'hard': 177, 'why': 178, 'white': 179, 'hair': 180, 'should': 181, 'years': 182, 'seemed': 183, 'called': 184, 'turned': 185, 'enough': 186, 'am': 187, 'hands': 188, 'three': 189, 'beside': 190, 'stone': 191, 'feet': 192, 'found': 193, "don't": 194, 'our': 195, 'khal': 196, 'until': 197, 'against': 198, 'joffrey': 199, 'half': 200, 'fingers': 201, 'grey': 202, 'queen': 203, 'nothing': 204, 'much': 205, 'ever': 206, 'small': 207, 'door': 208, 'think': 209, 'words': 210, 'knight': 211, 'girl': 212, 'while': 213, 'between': 214, 'gone': 215, 'stood': 216, 'felt': 217, 'eddard': 218, 'gold': 219, 'dark': 220, 'hear': 221, 'under': 222, 'put': 223, 'steel': 224, 'every': 225, 'children': 226, 'cold': 227, 'beneath': 228, 'watch': 229, 'right': 230, 'done': 231, 'drogo': 232, 'snow': 233, 'just': 234, 'place': 235, 'mother': 236, 'sister': 237, 'moment': 238, 'need': 239, 'seen': 240, 'life': 241, "i'm": 242, 'herself': 243, 'fire': 244, 'jorah': 245, 'find': 246, 'any': 247, 'fear': 248, 'arms': 249, 'woman': 250, 'give': 251, 'began': 252, 'silver': 253, 'side': 254, 'name': 255, 'end': 256, 'these': 257, 'shall': 258, 'castle': 259, 'those': 260, 'lords': 261, 'dothraki': 262, 'many': 263, 'leave': 264, 'always': 265, 'others': 266, 'child': 267, 'littlefinger': 268, 'north': 269, 'far': 270, 'prince': 271, 'room': 272, 'honor': 273, 'seven': 274, 'smile': 275, 'horses': 276, 'yes': 277, 'perhaps': 278, 'cloak': 279, 'wine': 280, 'mormont': 281, 'rode': 282, 'arm': 283, 'mouth': 284, 'sweet': 285, 'word': 286, 'jaime': 287, 'sent': 288, 'wind': 289, "i'll": 290, 'walls': 291, 'water': 292, 'house': 293, 'taken': 294, 'another': 295, 'ride': 296, 'young': 297, 'luwin': 298, 'iron': 299, 'feel': 300, 'tower': 301, 'close': 302, 'sat': 303, "it's": 304, 'almost': 305, 'tywin': 306, 'swords':  ...
# total words: 12251

# %%
sent_seq = to_sequences(tokenizer=tokenizer,X_data=sentences)

# %%
sent_seq[:3]
# Out:
# [[5, 1029, 6, 552, 3, 244], [5, 1248, 6, 2171], [7746]]

# %%
input_seq = seq_gen(sent_seq)

# %%
input_seq[:10]
# Out:
# [[5, 1029],
#  [5, 1029, 6],
#  [5, 1029, 6, 552],
#  [5, 1029, 6, 552, 3],
#  [5, 1029, 6, 552, 3, 244],
#  [5, 1248],
#  [5, 1248, 6],
#  [5, 1248, 6, 2171],
#  [67, 181],
#  [67, 181, 1347]]

# %%
padded_seq = to_padding(input_seq, 
                        MAX_LENGTH=MAX_LENGTH,
                        PADDING_TYPE=PADDING_TYPE,
                        TRUNC_TYPE=TRUNC_TYPE
                        )

# %%
padded_seq.shape
# Out:
# (289204, 225)

# %% [markdown]
# ### 5. Dataset Preparation

# %%
# Create inputs and label by splitting the last token in the subphrases
xs, labels = padded_seq[:, :-1], padded_seq[:, -1]

# %%
# Convert the label into one-hot arrays
ys = tf.keras.utils.to_categorical(labels, num_classes=total_words)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# c:\Users\91981\Desktop\GREAT LEARNING\FROM SCRATCH LEARNING\PROJETCS\Text_Generation_with_LSTM\1_SARCASM_Classifier_LSTM.ipynb Cell 26 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/91981/Desktop/GREAT%20LEARNING/FROM%20SCRATCH%20LEARNING/PROJETCS/Text_Generation_with_LSTM/1_SARCASM_Classifier_LSTM.ipynb#Y101sZmlsZQ%3D%3D?line=0'>1</a> # Convert the label into one-hot arrays
# ----> <a href='vscode-notebook-cell:/c%3A/Users/91981/Desktop/GREAT%20LEARNING/FROM%20SCRATCH%20LEARNING/PROJETCS/Text_Generation_with_LSTM/1_SARCASM_Classifier_LSTM.ipynb#Y101sZmlsZQ%3D%3D?line=1'>2</a> ys = tf.keras.utils.to_categorical(labels, num_classes=total_words)
#
# File c:\Users\91981\anaconda3\Lib\site-packages\keras\src\utils\np_utils.py:73, in to_categorical(y, num_classes, dtype)
#      71     num_classes = np.max(y) + 1
#      72 n = y.shape[0]
# ---> 73 categorical = np.zeros((n, num_classes), dtype=dtype)
#      74 categorical[np.arange(n), y] = 1
#      75 output_shape = input_shape + (num_classes,)
#
# MemoryError: Unable to allocate 13.2 GiB for an array with shape (289204, 12251) and data type float32

# %% [markdown]
# ### 6. LSTM +BIDIRECTIONAL

# %% [markdown]
# ##### Callbacks

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0.0001,
    patience=5,
    verbose=0,
    mode='auto',
    # baseline=None,
    restore_best_weights=True,
    # start_from_epoch=0
)

# Saving the best model and its weights to given path
checkpoint_filepath = 'models/model_checkpoint_LSTM.h5'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    verbose=1,
    # save_weights_only=True,
    save_best_only=True,
    monitor='val_loss',
    mode='auto'
)

# %% [markdown]
# ##### Model Training

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Build the model
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(
        VOCAB_SIZE, EMBEDDING_DIM, input_length=MAX_LENGTH, name="embedding"),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(30, name="rnn1_30", return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(50, name="rnn2_50", return_sequences=False)),

    # tf.keras.layers.Flatten(),

    tf.keras.layers.Dense(120, activation='relu', name="dense32"),
    tf.keras.layers.BatchNormalization(name="batch1"),
    tf.keras.layers.Dropout(0.5, name="dropout1"),

    tf.keras.layers.Dense(80, activation='relu', name="dense16"),
    tf.keras.layers.BatchNormalization(name="batch2"),
    tf.keras.layers.Dropout(0.4, name="dropout2"),


    tf.keras.layers.Dense(1, activation='sigmoid', name="last_dense1")
])

# Print the model summary
model.summary()

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001),
              loss='binary_crossentropy',
              metrics=['binary_accuracy'])

# %%
history = model.fit(train_dataset,
          validation_data=test_dataset,
          epochs=30,
          verbose=2,
          callbacks=[early_stopping, 
                     model_checkpoint_callback])

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 5))

ax[0].plot(history.history['loss'], label="train_loss")
ax[0].plot(history.history['val_loss'], label="val_loss")
ax[0].set_title("SCE loss function")
ax[0].legend()

ax[1].plot(history.history['binary_accuracy'], label="train_acc")
ax[1].plot(history.history['val_binary_accuracy'], label="val_acc")
ax[1].set_title("Accuracy Metric function")
ax[1].legend()
plt.tight_layout()
plt.show()
